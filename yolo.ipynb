# %%
import cv2
import numpy as np

# %%
! wget "https://pjreddie.com/media/files/yolov3.weights"
# Out:
# --2023-03-14 16:55:54--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  1.80MB/s    in 2m 31s
#
# 2023-03-14 16:58:25 (1.56 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
net = cv2.dnn.readNet("yolov3.weights","yolov3.cfg")

# %%
layer_names = net.getLayerNames()
print(layer_names)
# Out:
# ('conv_0', 'bn_0', 'leaky_1', 'conv_1', 'bn_1', 'leaky_2', 'conv_2', 'bn_2', 'leaky_3', 'conv_3', 'bn_3', 'leaky_4', 'shortcut_4', 'conv_5', 'bn_5', 'leaky_6', 'conv_6', 'bn_6', 'leaky_7', 'conv_7', 'bn_7', 'leaky_8', 'shortcut_8', 'conv_9', 'bn_9', 'leaky_10', 'conv_10', 'bn_10', 'leaky_11', 'shortcut_11', 'conv_12', 'bn_12', 'leaky_13', 'conv_13', 'bn_13', 'leaky_14', 'conv_14', 'bn_14', 'leaky_15', 'shortcut_15', 'conv_16', 'bn_16', 'leaky_17', 'conv_17', 'bn_17', 'leaky_18', 'shortcut_18', 'conv_19', 'bn_19', 'leaky_20', 'conv_20', 'bn_20', 'leaky_21', 'shortcut_21', 'conv_22', 'bn_22', 'leaky_23', 'conv_23', 'bn_23', 'leaky_24', 'shortcut_24', 'conv_25', 'bn_25', 'leaky_26', 'conv_26', 'bn_26', 'leaky_27', 'shortcut_27', 'conv_28', 'bn_28', 'leaky_29', 'conv_29', 'bn_29', 'leaky_30', 'shortcut_30', 'conv_31', 'bn_31', 'leaky_32', 'conv_32', 'bn_32', 'leaky_33', 'shortcut_33', 'conv_34', 'bn_34', 'leaky_35', 'conv_35', 'bn_35', 'leaky_36', 'shortcut_36', 'conv_37', 'bn_37', 'leaky_38', 'conv_38', 'bn_38', 'leaky_39', 'conv_39', 'bn_39', 'leaky_40', 'shortcut_40', 'conv_41', 'bn_41', 'leaky_42', 'conv_42', 'bn_42', 'leaky_43', 'shortcut_43', 'conv_44', 'bn_44', 'leaky_45', 'conv_45', 'bn_45', 'leaky_46', 'shortcut_46', 'conv_47', 'bn_47', 'leaky_48', 'conv_48', 'bn_48', 'leaky_49', 'shortcut_49', 'conv_50', 'bn_50', 'leaky_51', 'conv_51', 'bn_51', 'leaky_52', 'shortcut_52', 'conv_53', 'bn_53', 'leaky_54', 'conv_54', 'bn_54', 'leaky_55', 'shortcut_55', 'conv_56', 'bn_56', 'leaky_57', 'conv_57', 'bn_57', 'leaky_58', 'shortcut_58', 'conv_59', 'bn_59', 'leaky_60', 'conv_60', 'bn_60', 'leaky_61', 'shortcut_61', 'conv_62', 'bn_62', 'leaky_63', 'conv_63', 'bn_63', 'leaky_64', 'conv_64', 'bn_64', 'leaky_65', 'shortcut_65', 'conv_66', 'bn_66', 'leaky_67', 'conv_67', 'bn_67', 'leaky_68', 'shortcut_68', 'conv_69', 'bn_69', 'leaky_70', 'conv_70', 'bn_70', 'leaky_71', 'shortcut_71', 'conv_72', 'bn_72', 'leaky_73', 'conv_73', 'bn_73', 'leaky_74', 'shortcut_74', 'conv_75', 'bn_75', 'leaky_76', 'conv_76', 'bn_76', 'leaky_77', 'conv_77', 'bn_77', 'leaky_78', 'conv_78', 'bn_78', 'leaky_79', 'conv_79', 'bn_79', 'leaky_80', 'conv_80', 'bn_80', 'leaky_81', 'conv_81', 'permute_82', 'yolo_82', 'identity_83', 'conv_84', 'bn_84', 'leaky_85', 'upsample_85', 'concat_86', 'conv_87', 'bn_87', 'leaky_88', 'conv_88', 'bn_88', 'leaky_89', 'conv_89', 'bn_89', 'leaky_90', 'conv_90', 'bn_90', 'leaky_91', 'conv_91', 'bn_91', 'leaky_92', 'conv_92', 'bn_92', 'leaky_93', 'conv_93', 'permute_94', 'yolo_94', 'identity_95', 'conv_96', 'bn_96', 'leaky_97', 'upsample_97', 'concat_98', 'conv_99', 'bn_99', 'leaky_100', 'conv_100', 'bn_100', 'leaky_101', 'conv_101', 'bn_101', 'leaky_102', 'conv_102', 'bn_102', 'leaky_103', 'conv_103', 'bn_103', 'leaky_104', 'conv_104', 'bn_104', 'leaky_105', 'conv_105', 'permute_106', 'yolo_106')

# %%
# Visualize the structure of the network
for layer_name in layer_names:
    layer = net.getLayer(layer_name)
    print(layer.type)
    if layer.type == 'Convolution':
        output_shape = layer.blobs[0].shape
        print(layer_name, output_shape)
# Out:
# Convolution
# conv_0 (32, 3, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_1 (64, 32, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_2 (32, 64, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_3 (64, 32, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_5 (128, 64, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_6 (64, 128, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_7 (128, 64, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_9 (64, 128, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_10 (128, 64, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_12 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_13 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_14 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_16 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_17 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_19 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_20 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_22 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_23 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_25 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_26 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_28 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_29 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_31 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_32 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_34 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_35 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_37 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_38 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_39 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_41 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_42 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_44 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_45 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_47 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_48 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_50 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_51 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_53 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_54 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_56 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_57 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_59 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_60 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_62 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_63 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_64 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_66 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_67 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_69 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_70 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_72 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_73 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Eltwise
# Convolution
# conv_75 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_76 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_77 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_78 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_79 (512, 1024, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_80 (1024, 512, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_81 (255, 1024, 1, 1)
# Permute
# Region
# Identity
# Convolution
# conv_84 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Resize
# Concat
# Convolution
# conv_87 (256, 768, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_88 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_89 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_90 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_91 (256, 512, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_92 (512, 256, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_93 (255, 512, 1, 1)
# Permute
# Region
# Identity
# Convolution
# conv_96 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Resize
# Concat
# Convolution
# conv_99 (128, 384, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_100 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_101 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_102 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_103 (128, 256, 1, 1)
# BatchNorm
# ReLU
# Convolution
# conv_104 (256, 128, 3, 3)
# BatchNorm
# ReLU
# Convolution
# conv_105 (255, 256, 1, 1)
# Permute
# Region

# %%
layer.blobs[0].shape
# Out:
# (1, 6)
